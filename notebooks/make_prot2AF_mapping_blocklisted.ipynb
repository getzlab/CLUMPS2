# %%
import pandas as pd
import numpy as np
from prody import parsePDBStream, confProDy,parsePDBHeader
from clumps.utils import gunzipper, AMINO_ACID_MAP
import itertools
import glob
import os


#pdb structure list from Alphafold
afdir = '/home/adunford/afref/UP000005640_9606_HUMAN_v3/'
afpdblist = pd.Series([path.replace(afdir,'') for path in glob.glob('%s/*pdb.gz' % afdir)])
minconf = 50 
bl_length = 20
minlength = 10

#prot2AF mapping - needed to loop over, scatter/gather all structures
#current version of clumps seems to depend on having the 4 character code in order to access pdb structures
#may consider changing hard-coded line that requires above
#new version may have 1:1 uniprot:structure connection 
p2af = pd.DataFrame(columns=['u1', #uniprot id
                             'u2', #also uniprot iD (should be the same for AF, )
                             'struct', #name of structure/chain - 1 chain per peptide in AF?
                             'blat', #- not relevant for AF
                             'AA:AA list' #colon separated amino acid positions - should be 1:1, 2:2 etc. for AF? - revisit this
                            ])
#select uniprot in file name which has format AF-{Uniprotid}-F#-model_v3.pdb.gz
p2af['u1'] = [x[1] for x in afpdblist.str.split('-')]
p2af['u2'] = p2af['u1']
p2af['blat'] = '-'

#p2af.index = p2af['u1']
p2af = p2af.sort_values('u1')


p2af.index = np.arange(0, len(p2af))

for i in np.arange(0,len(p2af.index)):
    afid = hex(int('1000',16)+i)[2:]
    g = p2af.index[i]
    p2af.iloc[i,2] = '%s-A' % afid



confProDy(verbosity='none')

out_dir = 'af_dir'
if not os.path.exists(out_dir):
    os.mkdir(out_dir)
    
for uid in np.unique(p2af['u1']):
    nuid = sum(p2af['u1'] == uid)
    auid = len(afpdblist[afpdblist.str.contains(uid)])
    if nuid!=auid:
        msg = "%s entries of %s found in protein-af mapping, %s entries found in alphafold" % (nuid,uid,auid)
        print(msg)
    pstructs = p2af.loc[p2af['u1'] == uid,'struct'].values
    ix = p2af.loc[p2af['u1'] == uid].index

    for j in np.arange(0,nuid):
        affile = '%sAF-%s-F%s-model_v3.pdb.gz' % (afdir,uid,j+1)
        with gunzipper(affile) as afstream: 
            try:
                aa = parsePDBStream(afstream)
                afheader = parsePDBHeader(affile)
            except:
                print('failed to load pdb struct %s for %s' %(affile, uid))
                continue
            afstart,_,gstart = afheader['A'].dbrefs[0].first
            afend,_,gend = afheader['A'].dbrefs[0].last
            aaaa = ''
            afaa = np.arange(afstart,afend+1)
            gaa = np.arange(gstart,gend+1)
            xx = aa.getResnums()
            #do this check before anything else. For some reason sometimes start/end values in header get truncated
            #e.g. 1400 gets read as 14.  example structure with issue is AF-A0A087WUL8-F8-model_v3.pdb.gz
            if len(gaa) != len(afaa):
                print('length mismatch for %s.  AF struct is length %s, while genomic length is %s' % (uid, len(afaa),len(gaa)))
                continue
            #think this one is unnecessary as I'm not building 3d model yet
            #yy = aa.getCoords()
            zz = aa.getResnames()
            bb = aa.getBetas()
            pdb_resids = {}
            for i in range(len(xx)):
                pdb_resids[xx[i]] = (zz[i] in AMINO_ACID_MAP) and bb[i] > minconf
            coord = pd.Series(list(pdb_resids.keys()))
            quals = pd.Series(list(pdb_resids.values()))
            tids = coord[quals].tolist()
            fids = coord[quals != True]


            fids = np.split(fids,np.where(np.diff(fids)>1)[0]+1)
            for i in fids:
                ##print(len(i))
                if len(i) < bl_length:
                    tids = tids + i.tolist()
            pdb_resids = sorted(tids)
            #find longest contiguous run of quality amino acids
            #splits list into lists demarcated 
            #pdb_resids = max(np.split(pdb_resids, np.where(np.diff(pdb_resids) >= bl_length)[0] + 1), key=len).tolist()
            if len(pdb_resids)<=minlength:
                print ('no amino acid sequences longer than %s of sufficient quality for %s' % (minlength ,uid))
                continue
            #convert list of lists  back into single list.  Will fail if already a list.
            #try:
            #    pdb_resids = list(itertools.chain.from_iterable(pdb_resids[:]))
            #except:
            #    print("only one contig for %s" %  uid)
            #subtract 1 from each pdb resnumber to make it consistent with an index
            pdb_resids = [a - 1 for a in pdb_resids]
            afaa = afaa[pdb_resids]
            gaa = gaa[pdb_resids]


            for i in np.arange(0,len(afaa)):
                aai = '%s:%s ' %(gaa[i],afaa[i])
                aaaa = aaaa + (aai)
            #must remove trailing space or postprocessing will fail
            aaaa = aaaa.strip()
            p2af.loc[ix[j],'AA:AA list'] = aaaa

            if not os.path.exists(affile):
                print('file not found: %s' %affile)
                continue
            pstruct = pstructs[j]
            pstruct = str(pstruct[:-2])
            subdir=str(pstruct[1:3])
            cmd = 'cp %s %s/%s/pdb%s.ent.gz' %(affile,out_dir,subdir,pstruct)
            if not os.path.exists('%s/%s' %(out_dir,subdir)):
                os.mkdir('%s/%s' %(out_dir,subdir))
            os.system(cmd)

p2af = p2af.loc[~p2af['AA:AA list'].isna()]
#print out list of prot2AF mapping
p2af.to_csv('uniprot2af_map.txt',
            sep='\t',
            header=False,
            index=False)
out_dir = 'prot2AF_chunks'
chunk_length= 75
if not os.path.exists(out_dir):
    os.mkdir(out_dir)
gl = len(p2af.index)
start = 0
end = chunk_length
i = 0
while end < gl:
    if i < 10:
        num = '0000%s' %i
    elif i < 100:
        num = '000%s' %i
    elif i < 1000:
        num = '00%s' %i
    fn = 'prot2AF_chunks/prot2af_%s.gz' %num
    p2af.iloc[start:end].to_csv(fn,
            sep='\t',
            header=False,
            index=False)
    i = i + 1
    start = end
    end = end+chunk_length
end = gl


if i < 10:
    num = '0000%s' %i
elif i < 100:
    num = '000%s' %i
elif i < 1000:
    num = '00%s' %i
fn = 'prot2AF_chunks/prot2af_%s.gz' %num

p2af.iloc[start:end].to_csv(fn,
        sep='\t',
        header=False,
        index=False)
# Out:
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A024R1R8-F1-model_v3.pdb.gz for A0A024R1R8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A024RBG1-F1-model_v3.pdb.gz for A0A024RBG1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A024RCN7-F1-model_v3.pdb.gz for A0A024RCN7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6H5-F1-model_v3.pdb.gz for A0A075B6H5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6H7-F1-model_v3.pdb.gz for A0A075B6H7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6H8-F1-model_v3.pdb.gz for A0A075B6H8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6H9-F1-model_v3.pdb.gz for A0A075B6H9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6I0-F1-model_v3.pdb.gz for A0A075B6I0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6I1-F1-model_v3.pdb.gz for A0A075B6I1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6I3-F1-model_v3.pdb.gz for A0A075B6I3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6I4-F1-model_v3.pdb.gz for A0A075B6I4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6I6-F1-model_v3.pdb.gz for A0A075B6I6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6I7-F1-model_v3.pdb.gz for A0A075B6I7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6I9-F1-model_v3.pdb.gz for A0A075B6I9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6J1-F1-model_v3.pdb.gz for A0A075B6J1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6J2-F1-model_v3.pdb.gz for A0A075B6J2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6J6-F1-model_v3.pdb.gz for A0A075B6J6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6J9-F1-model_v3.pdb.gz for A0A075B6J9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6K0-F1-model_v3.pdb.gz for A0A075B6K0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6K2-F1-model_v3.pdb.gz for A0A075B6K2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6K4-F1-model_v3.pdb.gz for A0A075B6K4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6K5-F1-model_v3.pdb.gz for A0A075B6K5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6K6-F1-model_v3.pdb.gz for A0A075B6K6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6L2-F1-model_v3.pdb.gz for A0A075B6L2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6L6-F1-model_v3.pdb.gz for A0A075B6L6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6N1-F1-model_v3.pdb.gz for A0A075B6N1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6N2-F1-model_v3.pdb.gz for A0A075B6N2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6N3-F1-model_v3.pdb.gz for A0A075B6N3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6N4-F1-model_v3.pdb.gz for A0A075B6N4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6P5-F1-model_v3.pdb.gz for A0A075B6P5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6Q5-F1-model_v3.pdb.gz for A0A075B6Q5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6R0-F1-model_v3.pdb.gz for A0A075B6R0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6R2-F1-model_v3.pdb.gz for A0A075B6R2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6R9-F1-model_v3.pdb.gz for A0A075B6R9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6S0-F1-model_v3.pdb.gz for A0A075B6S0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6S2-F1-model_v3.pdb.gz for A0A075B6S2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6S4-F1-model_v3.pdb.gz for A0A075B6S4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6S5-F1-model_v3.pdb.gz for A0A075B6S5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6S6-F1-model_v3.pdb.gz for A0A075B6S6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6S9-F1-model_v3.pdb.gz for A0A075B6S9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6T6-F1-model_v3.pdb.gz for A0A075B6T6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6T7-F1-model_v3.pdb.gz for A0A075B6T7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6T8-F1-model_v3.pdb.gz for A0A075B6T8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6U4-F1-model_v3.pdb.gz for A0A075B6U4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6U6-F1-model_v3.pdb.gz for A0A075B6U6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6V2-F1-model_v3.pdb.gz for A0A075B6V2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6V5-F1-model_v3.pdb.gz for A0A075B6V5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6W5-F1-model_v3.pdb.gz for A0A075B6W5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6X5-F1-model_v3.pdb.gz for A0A075B6X5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6Y3-F1-model_v3.pdb.gz for A0A075B6Y3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B6Y9-F1-model_v3.pdb.gz for A0A075B6Y9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B700-F1-model_v3.pdb.gz for A0A075B700
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B706-F1-model_v3.pdb.gz for A0A075B706
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B734-F1-model_v3.pdb.gz for A0A075B734
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B759-F1-model_v3.pdb.gz for A0A075B759
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B767-F1-model_v3.pdb.gz for A0A075B767
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B7B6-F1-model_v3.pdb.gz for A0A075B7B6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B7B8-F1-model_v3.pdb.gz for A0A075B7B8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B7D0-F1-model_v3.pdb.gz for A0A075B7D0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B7D4-F1-model_v3.pdb.gz for A0A075B7D4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B7D8-F1-model_v3.pdb.gz for A0A075B7D8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B7E8-F1-model_v3.pdb.gz for A0A075B7E8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B7F0-F1-model_v3.pdb.gz for A0A075B7F0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A075B7F1-F1-model_v3.pdb.gz for A0A075B7F1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WSX0-F1-model_v3.pdb.gz for A0A087WSX0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WSY4-F1-model_v3.pdb.gz for A0A087WSY4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WSY6-F1-model_v3.pdb.gz for A0A087WSY6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WSZ0-F1-model_v3.pdb.gz for A0A087WSZ0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WSZ9-F1-model_v3.pdb.gz for A0A087WSZ9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WT01-F1-model_v3.pdb.gz for A0A087WT01
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WT02-F1-model_v3.pdb.gz for A0A087WT02
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WT03-F1-model_v3.pdb.gz for A0A087WT03
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WTH1-F1-model_v3.pdb.gz for A0A087WTH1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WTH5-F1-model_v3.pdb.gz for A0A087WTH5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WUL8-F1-model_v3.pdb.gz for A0A087WUL8
# length mismatch for A0A087WUL8.  AF struct is length 1400, while genomic length is 15
# length mismatch for A0A087WUL8.  AF struct is length 1400, while genomic length is 15
# length mismatch for A0A087WUL8.  AF struct is length 1400, while genomic length is 15
# length mismatch for A0A087WUL8.  AF struct is length 1400, while genomic length is 15
# length mismatch for A0A087WUL8.  AF struct is length 1400, while genomic length is 15
# length mismatch for A0A087WUL8.  AF struct is length 1400, while genomic length is 15
# length mismatch for A0A087WUL8.  AF struct is length 1400, while genomic length is 15
# length mismatch for A0A087WUL8.  AF struct is length 1400, while genomic length is 15
# length mismatch for A0A087WUL8.  AF struct is length 1400, while genomic length is 15
# length mismatch for A0A087WUL8.  AF struct is length 1400, while genomic length is 15
# length mismatch for A0A087WUL8.  AF struct is length 1400, while genomic length is 15
# length mismatch for A0A087WUL8.  AF struct is length 1400, while genomic length is 15
# length mismatch for A0A087WUL8.  AF struct is length 1243, while genomic length is 13
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WUM9-F1-model_v3.pdb.gz for A0A087WUM9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WUV0-F1-model_v3.pdb.gz for A0A087WUV0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WV53-F1-model_v3.pdb.gz for A0A087WV53
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WV62-F1-model_v3.pdb.gz for A0A087WV62
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WVF3-F1-model_v3.pdb.gz for A0A087WVF3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WW49-F1-model_v3.pdb.gz for A0A087WW49
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WW87-F1-model_v3.pdb.gz for A0A087WW87
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WWA1-F1-model_v3.pdb.gz for A0A087WWA1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WX78-F1-model_v3.pdb.gz for A0A087WX78
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WXM9-F1-model_v3.pdb.gz for A0A087WXM9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WXS9-F1-model_v3.pdb.gz for A0A087WXS9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WYE8-F1-model_v3.pdb.gz for A0A087WYE8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087WZ39-F1-model_v3.pdb.gz for A0A087WZ39
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087X0K7-F1-model_v3.pdb.gz for A0A087X0K7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087X0M5-F1-model_v3.pdb.gz for A0A087X0M5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087X179-F1-model_v3.pdb.gz for A0A087X179
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087X1C1-F1-model_v3.pdb.gz for A0A087X1C1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087X1C5-F1-model_v3.pdb.gz for A0A087X1C5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087X1G2-F1-model_v3.pdb.gz for A0A087X1G2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A087X1L8-F1-model_v3.pdb.gz for A0A087X1L8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A096LNP1-F1-model_v3.pdb.gz for A0A096LNP1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A096LNT9-F1-model_v3.pdb.gz for A0A096LNT9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A096LNW5-F1-model_v3.pdb.gz for A0A096LNW5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A096LP01-F1-model_v3.pdb.gz for A0A096LP01
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A096LP49-F1-model_v3.pdb.gz for A0A096LP49
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A096LP55-F1-model_v3.pdb.gz for A0A096LP55
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A096LPG2-F1-model_v3.pdb.gz for A0A096LPG2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A096LPH7-F1-model_v3.pdb.gz for A0A096LPH7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A096LPI5-F1-model_v3.pdb.gz for A0A096LPI5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A096LPK6-F1-model_v3.pdb.gz for A0A096LPK6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A096LPK9-F1-model_v3.pdb.gz for A0A096LPK9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MRZ7-F1-model_v3.pdb.gz for A0A0A0MRZ7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MRZ8-F1-model_v3.pdb.gz for A0A0A0MRZ8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MRZ9-F1-model_v3.pdb.gz for A0A0A0MRZ9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MS00-F1-model_v3.pdb.gz for A0A0A0MS00
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MS01-F1-model_v3.pdb.gz for A0A0A0MS01
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MS02-F1-model_v3.pdb.gz for A0A0A0MS02
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MS03-F1-model_v3.pdb.gz for A0A0A0MS03
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MS04-F1-model_v3.pdb.gz for A0A0A0MS04
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MS05-F1-model_v3.pdb.gz for A0A0A0MS05
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MS06-F1-model_v3.pdb.gz for A0A0A0MS06
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MS14-F1-model_v3.pdb.gz for A0A0A0MS14
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MS15-F1-model_v3.pdb.gz for A0A0A0MS15
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MT36-F1-model_v3.pdb.gz for A0A0A0MT36
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MT70-F1-model_v3.pdb.gz for A0A0A0MT70
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MT76-F1-model_v3.pdb.gz for A0A0A0MT76
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MT82-F1-model_v3.pdb.gz for A0A0A0MT82
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MT86-F1-model_v3.pdb.gz for A0A0A0MT86
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MT87-F1-model_v3.pdb.gz for A0A0A0MT87
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MT93-F1-model_v3.pdb.gz for A0A0A0MT93
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MT94-F1-model_v3.pdb.gz for A0A0A0MT94
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MT99-F1-model_v3.pdb.gz for A0A0A0MT99
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A0MTA7-F1-model_v3.pdb.gz for A0A0A0MTA7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A6YYC5-F1-model_v3.pdb.gz for A0A0A6YYC5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A6YYD4-F1-model_v3.pdb.gz for A0A0A6YYD4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A6YYG2-F1-model_v3.pdb.gz for A0A0A6YYG2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A6YYG3-F1-model_v3.pdb.gz for A0A0A6YYG3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A6YYJ7-F1-model_v3.pdb.gz for A0A0A6YYJ7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A6YYK1-F1-model_v3.pdb.gz for A0A0A6YYK1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A6YYK4-F1-model_v3.pdb.gz for A0A0A6YYK4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A6YYK6-F1-model_v3.pdb.gz for A0A0A6YYK6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A6YYK7-F1-model_v3.pdb.gz for A0A0A6YYK7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0A6YYL3-F1-model_v3.pdb.gz for A0A0A6YYL3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J1T7-F1-model_v3.pdb.gz for A0A0B4J1T7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J1U3-F1-model_v3.pdb.gz for A0A0B4J1U3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J1U4-F1-model_v3.pdb.gz for A0A0B4J1U4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J1U6-F1-model_v3.pdb.gz for A0A0B4J1U6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J1U7-F1-model_v3.pdb.gz for A0A0B4J1U7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J1V0-F1-model_v3.pdb.gz for A0A0B4J1V0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J1V1-F1-model_v3.pdb.gz for A0A0B4J1V1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J1V2-F1-model_v3.pdb.gz for A0A0B4J1V2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J1V6-F1-model_v3.pdb.gz for A0A0B4J1V6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J1V7-F1-model_v3.pdb.gz for A0A0B4J1V7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J1W7-F1-model_v3.pdb.gz for A0A0B4J1W7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J1X5-F1-model_v3.pdb.gz for A0A0B4J1X5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J1X8-F1-model_v3.pdb.gz for A0A0B4J1X8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J1Y8-F1-model_v3.pdb.gz for A0A0B4J1Y8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J1Y9-F1-model_v3.pdb.gz for A0A0B4J1Y9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J1Z2-F1-model_v3.pdb.gz for A0A0B4J1Z2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J200-F1-model_v3.pdb.gz for A0A0B4J200
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J234-F1-model_v3.pdb.gz for A0A0B4J234
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J235-F1-model_v3.pdb.gz for A0A0B4J235
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J237-F1-model_v3.pdb.gz for A0A0B4J237
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J238-F1-model_v3.pdb.gz for A0A0B4J238
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J240-F1-model_v3.pdb.gz for A0A0B4J240
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J241-F1-model_v3.pdb.gz for A0A0B4J241
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J244-F1-model_v3.pdb.gz for A0A0B4J244
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J245-F1-model_v3.pdb.gz for A0A0B4J245
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J248-F1-model_v3.pdb.gz for A0A0B4J248
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J249-F1-model_v3.pdb.gz for A0A0B4J249
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J262-F1-model_v3.pdb.gz for A0A0B4J262
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J263-F1-model_v3.pdb.gz for A0A0B4J263
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J264-F1-model_v3.pdb.gz for A0A0B4J264
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J265-F1-model_v3.pdb.gz for A0A0B4J265
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J266-F1-model_v3.pdb.gz for A0A0B4J266
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J268-F1-model_v3.pdb.gz for A0A0B4J268
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J271-F1-model_v3.pdb.gz for A0A0B4J271
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J272-F1-model_v3.pdb.gz for A0A0B4J272
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J273-F1-model_v3.pdb.gz for A0A0B4J273
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J274-F1-model_v3.pdb.gz for A0A0B4J274
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J275-F1-model_v3.pdb.gz for A0A0B4J275
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J276-F1-model_v3.pdb.gz for A0A0B4J276
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J277-F1-model_v3.pdb.gz for A0A0B4J277
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J279-F1-model_v3.pdb.gz for A0A0B4J279
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J280-F1-model_v3.pdb.gz for A0A0B4J280
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J2A2-F1-model_v3.pdb.gz for A0A0B4J2A2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J2B6-F1-model_v3.pdb.gz for A0A0B4J2B6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J2B8-F1-model_v3.pdb.gz for A0A0B4J2B8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J2D5-F1-model_v3.pdb.gz for A0A0B4J2D5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J2D9-F1-model_v3.pdb.gz for A0A0B4J2D9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J2E0-F1-model_v3.pdb.gz for A0A0B4J2E0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J2E5-F1-model_v3.pdb.gz for A0A0B4J2E5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J2F0-F1-model_v3.pdb.gz for A0A0B4J2F0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J2F2-F1-model_v3.pdb.gz for A0A0B4J2F2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0B4J2H0-F1-model_v3.pdb.gz for A0A0B4J2H0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DGP1-F1-model_v3.pdb.gz for A0A0C4DGP1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH24-F1-model_v3.pdb.gz for A0A0C4DH24
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH25-F1-model_v3.pdb.gz for A0A0C4DH25
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH26-F1-model_v3.pdb.gz for A0A0C4DH26
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH27-F1-model_v3.pdb.gz for A0A0C4DH27
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH28-F1-model_v3.pdb.gz for A0A0C4DH28
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH29-F1-model_v3.pdb.gz for A0A0C4DH29
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH30-F1-model_v3.pdb.gz for A0A0C4DH30
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH31-F1-model_v3.pdb.gz for A0A0C4DH31
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH32-F1-model_v3.pdb.gz for A0A0C4DH32
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH33-F1-model_v3.pdb.gz for A0A0C4DH33
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH34-F1-model_v3.pdb.gz for A0A0C4DH34
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH35-F1-model_v3.pdb.gz for A0A0C4DH35
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH36-F1-model_v3.pdb.gz for A0A0C4DH36
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH38-F1-model_v3.pdb.gz for A0A0C4DH38
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH39-F1-model_v3.pdb.gz for A0A0C4DH39
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH41-F1-model_v3.pdb.gz for A0A0C4DH41
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH42-F1-model_v3.pdb.gz for A0A0C4DH42
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH43-F1-model_v3.pdb.gz for A0A0C4DH43
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH55-F1-model_v3.pdb.gz for A0A0C4DH55
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH59-F1-model_v3.pdb.gz for A0A0C4DH59
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH62-F1-model_v3.pdb.gz for A0A0C4DH62
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH63-F1-model_v3.pdb.gz for A0A0C4DH63
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH67-F1-model_v3.pdb.gz for A0A0C4DH67
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH68-F1-model_v3.pdb.gz for A0A0C4DH68
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH69-F1-model_v3.pdb.gz for A0A0C4DH69
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH72-F1-model_v3.pdb.gz for A0A0C4DH72
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH73-F1-model_v3.pdb.gz for A0A0C4DH73
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C4DH90-F1-model_v3.pdb.gz for A0A0C4DH90
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0C5B5G6-F1-model_v3.pdb.gz for A0A0C5B5G6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0D9SF12-F1-model_v3.pdb.gz for A0A0D9SF12
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JKD1-F1-model_v3.pdb.gz for A0A0G2JKD1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JKW9-F1-model_v3.pdb.gz for A0A0G2JKW9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JLE6-F1-model_v3.pdb.gz for A0A0G2JLE6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JLG4-F1-model_v3.pdb.gz for A0A0G2JLG4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JLM5-F1-model_v3.pdb.gz for A0A0G2JLM5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JLQ3-F1-model_v3.pdb.gz for A0A0G2JLQ3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JLW4-F1-model_v3.pdb.gz for A0A0G2JLW4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JMD5-F1-model_v3.pdb.gz for A0A0G2JMD5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JMH3-F1-model_v3.pdb.gz for A0A0G2JMH3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JMH6-F1-model_v3.pdb.gz for A0A0G2JMH6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JMI3-F1-model_v3.pdb.gz for A0A0G2JMI3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JMM0-F1-model_v3.pdb.gz for A0A0G2JMM0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JMP0-F1-model_v3.pdb.gz for A0A0G2JMP0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JMS6-F1-model_v3.pdb.gz for A0A0G2JMS6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JN01-F1-model_v3.pdb.gz for A0A0G2JN01
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JN53-F1-model_v3.pdb.gz for A0A0G2JN53
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JN68-F1-model_v3.pdb.gz for A0A0G2JN68
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JND7-F1-model_v3.pdb.gz for A0A0G2JND7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JNF4-F1-model_v3.pdb.gz for A0A0G2JNF4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JNG1-F1-model_v3.pdb.gz for A0A0G2JNG1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JNH3-F1-model_v3.pdb.gz for A0A0G2JNH3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JNJ9-F1-model_v3.pdb.gz for A0A0G2JNJ9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JNQ3-F1-model_v3.pdb.gz for A0A0G2JNQ3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JP20-F1-model_v3.pdb.gz for A0A0G2JP20
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JPB7-F1-model_v3.pdb.gz for A0A0G2JPB7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JPC4-F1-model_v3.pdb.gz for A0A0G2JPC4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JPF8-F1-model_v3.pdb.gz for A0A0G2JPF8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JPN4-F1-model_v3.pdb.gz for A0A0G2JPN4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JQ47-F1-model_v3.pdb.gz for A0A0G2JQ47
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JQF1-F1-model_v3.pdb.gz for A0A0G2JQF1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JQZ4-F1-model_v3.pdb.gz for A0A0G2JQZ4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JRQ6-F1-model_v3.pdb.gz for A0A0G2JRQ6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0G2JS06-F1-model_v3.pdb.gz for A0A0G2JS06
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YVY3-F1-model_v3.pdb.gz for A0A0J9YVY3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YW62-F1-model_v3.pdb.gz for A0A0J9YW62
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YWL9-F1-model_v3.pdb.gz for A0A0J9YWL9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YWP8-F1-model_v3.pdb.gz for A0A0J9YWP8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YWU9-F1-model_v3.pdb.gz for A0A0J9YWU9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YWX3-F1-model_v3.pdb.gz for A0A0J9YWX3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YX35-F1-model_v3.pdb.gz for A0A0J9YX35
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YX57-F1-model_v3.pdb.gz for A0A0J9YX57
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YX75-F1-model_v3.pdb.gz for A0A0J9YX75
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YX94-F1-model_v3.pdb.gz for A0A0J9YX94
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YXG5-F1-model_v3.pdb.gz for A0A0J9YXG5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YXM7-F1-model_v3.pdb.gz for A0A0J9YXM7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YXQ4-F1-model_v3.pdb.gz for A0A0J9YXQ4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YXV3-F1-model_v3.pdb.gz for A0A0J9YXV3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YXX1-F1-model_v3.pdb.gz for A0A0J9YXX1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YXY3-F1-model_v3.pdb.gz for A0A0J9YXY3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YY54-F1-model_v3.pdb.gz for A0A0J9YY54
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0J9YY99-F1-model_v3.pdb.gz for A0A0J9YY99
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0K0K1A3-F1-model_v3.pdb.gz for A0A0K0K1A3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0K0K1A5-F1-model_v3.pdb.gz for A0A0K0K1A5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0K0K1B3-F1-model_v3.pdb.gz for A0A0K0K1B3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0K0K1C0-F1-model_v3.pdb.gz for A0A0K0K1C0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0K0K1C4-F1-model_v3.pdb.gz for A0A0K0K1C4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0K0K1D8-F1-model_v3.pdb.gz for A0A0K0K1D8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0K0K1E9-F1-model_v3.pdb.gz for A0A0K0K1E9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0K0K1G6-F1-model_v3.pdb.gz for A0A0K0K1G6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0K0K1G8-F1-model_v3.pdb.gz for A0A0K0K1G8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0K2S4Q6-F1-model_v3.pdb.gz for A0A0K2S4Q6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0M3HER8-F1-model_v3.pdb.gz for A0A0M3HER8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0U1RQE8-F1-model_v3.pdb.gz for A0A0U1RQE8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0U1RQF7-F1-model_v3.pdb.gz for A0A0U1RQF7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0U1RQG5-F1-model_v3.pdb.gz for A0A0U1RQG5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0U1RQI7-F1-model_v3.pdb.gz for A0A0U1RQI7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0U1RQS6-F1-model_v3.pdb.gz for A0A0U1RQS6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0U1RR11-F1-model_v3.pdb.gz for A0A0U1RR11
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0U1RR37-F1-model_v3.pdb.gz for A0A0U1RR37
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0U1RRA0-F1-model_v3.pdb.gz for A0A0U1RRA0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0U1RRE5-F1-model_v3.pdb.gz for A0A0U1RRE5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0U1RRI6-F1-model_v3.pdb.gz for A0A0U1RRI6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0U1RRK4-F1-model_v3.pdb.gz for A0A0U1RRK4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0U1RRL7-F1-model_v3.pdb.gz for A0A0U1RRL7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0U1RRN3-F1-model_v3.pdb.gz for A0A0U1RRN3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A0X1KG70-F1-model_v3.pdb.gz for A0A0X1KG70
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A126GWB0-F1-model_v3.pdb.gz for A0A126GWB0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A126GWI2-F1-model_v3.pdb.gz for A0A126GWI2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A140G945-F1-model_v3.pdb.gz for A0A140G945
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A140T8X8-F1-model_v3.pdb.gz for A0A140T8X8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A140TA62-F1-model_v3.pdb.gz for A0A140TA62
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A140TA64-F1-model_v3.pdb.gz for A0A140TA64
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A140TA67-F1-model_v3.pdb.gz for A0A140TA67
# /usr/local/lib/python3.8/dist-packages/numpy/lib/shape_base.py:790: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sub_arys.append(_nx.swapaxes(sary[st:end], axis, 0))
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A191URJ7-F1-model_v3.pdb.gz for A0A191URJ7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTC6-F1-model_v3.pdb.gz for A0A1B0GTC6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTD5-F1-model_v3.pdb.gz for A0A1B0GTD5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTE1-F1-model_v3.pdb.gz for A0A1B0GTE1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTG8-F1-model_v3.pdb.gz for A0A1B0GTG8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTH6-F1-model_v3.pdb.gz for A0A1B0GTH6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTH9-F1-model_v3.pdb.gz for A0A1B0GTH9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTI1-F1-model_v3.pdb.gz for A0A1B0GTI1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTI8-F1-model_v3.pdb.gz for A0A1B0GTI8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTJ6-F1-model_v3.pdb.gz for A0A1B0GTJ6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTK4-F1-model_v3.pdb.gz for A0A1B0GTK4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTK5-F1-model_v3.pdb.gz for A0A1B0GTK5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTL2-F1-model_v3.pdb.gz for A0A1B0GTL2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTQ1-F1-model_v3.pdb.gz for A0A1B0GTQ1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTQ4-F1-model_v3.pdb.gz for A0A1B0GTQ4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTR0-F1-model_v3.pdb.gz for A0A1B0GTR0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTR3-F1-model_v3.pdb.gz for A0A1B0GTR3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTR4-F1-model_v3.pdb.gz for A0A1B0GTR4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTS1-F1-model_v3.pdb.gz for A0A1B0GTS1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTU1-F1-model_v3.pdb.gz for A0A1B0GTU1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTU2-F1-model_v3.pdb.gz for A0A1B0GTU2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTW7-F1-model_v3.pdb.gz for A0A1B0GTW7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTY4-F1-model_v3.pdb.gz for A0A1B0GTY4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GTZ2-F1-model_v3.pdb.gz for A0A1B0GTZ2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GU29-F1-model_v3.pdb.gz for A0A1B0GU29
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GU33-F1-model_v3.pdb.gz for A0A1B0GU33
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GU71-F1-model_v3.pdb.gz for A0A1B0GU71
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUA5-F1-model_v3.pdb.gz for A0A1B0GUA5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUA6-F1-model_v3.pdb.gz for A0A1B0GUA6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUA7-F1-model_v3.pdb.gz for A0A1B0GUA7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUA9-F1-model_v3.pdb.gz for A0A1B0GUA9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUC4-F1-model_v3.pdb.gz for A0A1B0GUC4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUI7-F1-model_v3.pdb.gz for A0A1B0GUI7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUJ8-F1-model_v3.pdb.gz for A0A1B0GUJ8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUL7-F1-model_v3.pdb.gz for A0A1B0GUL7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUQ0-F1-model_v3.pdb.gz for A0A1B0GUQ0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUS0-F1-model_v3.pdb.gz for A0A1B0GUS0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUS4-F1-model_v3.pdb.gz for A0A1B0GUS4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUT2-F1-model_v3.pdb.gz for A0A1B0GUT2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUU1-F1-model_v3.pdb.gz for A0A1B0GUU1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUV1-F1-model_v3.pdb.gz for A0A1B0GUV1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUV7-F1-model_v3.pdb.gz for A0A1B0GUV7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUV8-F1-model_v3.pdb.gz for A0A1B0GUV8
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUW6-F1-model_v3.pdb.gz for A0A1B0GUW6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUW7-F1-model_v3.pdb.gz for A0A1B0GUW7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUX0-F1-model_v3.pdb.gz for A0A1B0GUX0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUY1-F1-model_v3.pdb.gz for A0A1B0GUY1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GUZ9-F1-model_v3.pdb.gz for A0A1B0GUZ9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GV03-F1-model_v3.pdb.gz for A0A1B0GV03
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GV22-F1-model_v3.pdb.gz for A0A1B0GV22
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GV85-F1-model_v3.pdb.gz for A0A1B0GV85
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GV90-F1-model_v3.pdb.gz for A0A1B0GV90
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GV96-F1-model_v3.pdb.gz for A0A1B0GV96
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVB3-F1-model_v3.pdb.gz for A0A1B0GVB3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVD1-F1-model_v3.pdb.gz for A0A1B0GVD1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVG4-F1-model_v3.pdb.gz for A0A1B0GVG4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVG6-F1-model_v3.pdb.gz for A0A1B0GVG6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVH4-F1-model_v3.pdb.gz for A0A1B0GVH4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVH6-F1-model_v3.pdb.gz for A0A1B0GVH6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVH7-F1-model_v3.pdb.gz for A0A1B0GVH7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVK7-F1-model_v3.pdb.gz for A0A1B0GVK7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVM5-F1-model_v3.pdb.gz for A0A1B0GVM5
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVM6-F1-model_v3.pdb.gz for A0A1B0GVM6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVN3-F1-model_v3.pdb.gz for A0A1B0GVN3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVQ0-F1-model_v3.pdb.gz for A0A1B0GVQ0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVQ3-F1-model_v3.pdb.gz for A0A1B0GVQ3
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVR7-F1-model_v3.pdb.gz for A0A1B0GVR7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVS7-F1-model_v3.pdb.gz for A0A1B0GVS7
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVT2-F1-model_v3.pdb.gz for A0A1B0GVT2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVV1-F1-model_v3.pdb.gz for A0A1B0GVV1
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVX0-F1-model_v3.pdb.gz for A0A1B0GVX0
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVY2-F1-model_v3.pdb.gz for A0A1B0GVY2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVY4-F1-model_v3.pdb.gz for A0A1B0GVY4
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVZ2-F1-model_v3.pdb.gz for A0A1B0GVZ2
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVZ6-F1-model_v3.pdb.gz for A0A1B0GVZ6
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GVZ9-F1-model_v3.pdb.gz for A0A1B0GVZ9
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GW15-F1-model_v3.pdb.gz for A0A1B0GW15
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GW35-F1-model_v3.pdb.gz for A0A1B0GW35
# failed to load pdb struct /home/adunford/afref/UP000005640_9606_HUMAN_v3/AF-A0A1B0GW54-F1-model_v3.pdb.gz for A0A1B0GW54
# ...
# no amino acid sequences longer than 10 of sufficient quality for Q8TCU4
# no amino acid sequences longer than 10 of sufficient quality for Q8TCU4
# no amino acid sequences longer than 10 of sufficient quality for Q8TCU4
# no amino acid sequences longer than 10 of sufficient quality for Q8WU49
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# no amino acid sequences longer than 10 of sufficient quality for Q8WXI7
# length mismatch for Q8WXI7.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WXI7.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WXI7.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WXI7.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WXI7.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WXI7.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WXI7.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WXI7.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WXI7.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WXI7.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WXI7.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WXI7.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WXI7.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WXI7.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WXI7.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WXI7.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WXI7.  AF struct is length 1307, while genomic length is 11307
# no amino acid sequences longer than 10 of sufficient quality for Q8WXQ3
# no amino acid sequences longer than 10 of sufficient quality for Q8WY50
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 11400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 21400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 31400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 31400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 31400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 31400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 31400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 31400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 31400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 31400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 31400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 31400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 31400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 31400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 31400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 31400
# length mismatch for Q8WZ42.  AF struct is length 1400, while genomic length is 31400
# length mismatch for Q8WZ42.  AF struct is length 1350, while genomic length is 31350
# no amino acid sequences longer than 10 of sufficient quality for Q8WZ69
# no amino acid sequences longer than 10 of sufficient quality for Q96LM1
# no amino acid sequences longer than 10 of sufficient quality for Q96LS8
# no amino acid sequences longer than 10 of sufficient quality for Q96M78
# no amino acid sequences longer than 10 of sufficient quality for Q96M85
# no amino acid sequences longer than 10 of sufficient quality for Q96MC9
# no amino acid sequences longer than 10 of sufficient quality for Q96MT0
# no amino acid sequences longer than 10 of sufficient quality for Q96MT4
# no amino acid sequences longer than 10 of sufficient quality for Q96MU5
# no amino acid sequences longer than 10 of sufficient quality for Q96S07
# no amino acid sequences longer than 10 of sufficient quality for Q9BQ66
# no amino acid sequences longer than 10 of sufficient quality for Q9BR46
# no amino acid sequences longer than 10 of sufficient quality for Q9BRP9
# no amino acid sequences longer than 10 of sufficient quality for Q9BTD1
# no amino acid sequences longer than 10 of sufficient quality for Q9BYQ3
# no amino acid sequences longer than 10 of sufficient quality for Q9BYQ5
# no amino acid sequences longer than 10 of sufficient quality for Q9BYQ7
# no amino acid sequences longer than 10 of sufficient quality for Q9BYQ9
# no amino acid sequences longer than 10 of sufficient quality for Q9BYR0
# no amino acid sequences longer than 10 of sufficient quality for Q9BYR9
# no amino acid sequences longer than 10 of sufficient quality for Q9BYT5
# no amino acid sequences longer than 10 of sufficient quality for Q9BYU5
# no amino acid sequences longer than 10 of sufficient quality for Q9GZL8
# no amino acid sequences longer than 10 of sufficient quality for Q9H0A3
# no amino acid sequences longer than 10 of sufficient quality for Q9H3A6
# no amino acid sequences longer than 10 of sufficient quality for Q9H5L9
# no amino acid sequences longer than 10 of sufficient quality for Q9H8Q6
# no amino acid sequences longer than 10 of sufficient quality for Q9H8X3
# no amino acid sequences longer than 10 of sufficient quality for Q9P1J3
# no amino acid sequences longer than 10 of sufficient quality for Q9UKN1
# no amino acid sequences longer than 10 of sufficient quality for Q9UKN1
# no amino acid sequences longer than 10 of sufficient quality for Q9UKN1
# no amino acid sequences longer than 10 of sufficient quality for Q9UKN1
# no amino acid sequences longer than 10 of sufficient quality for Q9UKN1
# no amino acid sequences longer than 10 of sufficient quality for Q9UKN1
# no amino acid sequences longer than 10 of sufficient quality for Q9ULZ0
# no amino acid sequences longer than 10 of sufficient quality for Q9Y6Z4
# no amino acid sequences longer than 10 of sufficient quality for Q9Y6Z5
