# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import re
import os

intermediatedir = '/mnt/nfs/workspace/run_clumps_all_genes_MC3_notimeout/clumps_run_task__2023-09-05--22-30-53_eu0hviq_lhlq02y_q1x40sglal0vs/outputs/*/run_outdir/clumps_results/*'
interres = pd.Series(glob.glob(intermediatedir))
old_results = pd.read_csv('CLUMPS_2018_results.txt',sep='\t')
old_results
# Out:
#       GENE_NAMES UNIPROT_ID IN_CANCER_GENE_LISTS MAPPED_UNIPROT_ID  \
# 0            ATM     Q13315                C,S,M            Q13315
# 1           BRAF     P15056                C,S,M            P15056
# 2           MTOR     P42345                C,S,M            P42345
# 3         PIK3CA     P42336                C,S,M            P42336
# 4        PPP2R1A     P30153                C,S,M            P30153
# ...          ...        ...                  ...               ...
# 20312    TSPAN19     P0C672                  NaN            Q8ITD7
# 20313        TTN     Q8WZ42                  NaN            Q64487
# 20314       VWDE     Q8N2E2                  NaN            Q9Y5W5
# 20315     ZNF772     Q68DY9                  NaN            P03001
# 20316     ZNF835     Q9Y2P0                  NaN            D9IWL3
#
#       PDBID-CHAIN  PDB_FRAGMENT  UNIPROT_SEQ_LENGTH  MAP_START  MAP_END  \
# 0          5np1-A           NaN              3056.0          3     3056
# ...

# %%
UNIPROT_ID = pd.Series([])
PDBIDCHAIN = pd.Series([])
MAP_START  = pd.Series([])
CLUMPSP    = pd.Series([])


for f1 in interres:
    r1 = pd.read_csv(f1,sep='\t',comment='#',header=None)
    fn = os.path.basename(f1)
    strlist = fn.split('_')


    u1 = strlist[1]
    
    pdb = strlist[3]
    start = strlist[4]
    print(r1[2])
# Out:
# 0    8502/16000
# Name: 2, dtype: object
# 0    4535/16000
# Name: 2, dtype: object
# 0    8324/16000
# Name: 2, dtype: object
# 0    11333/16000
# Name: 2, dtype: object
# 0    5407/16000
# Name: 2, dtype: object
# 0    6727/16000
# Name: 2, dtype: object
# 0    10633/16000
# Name: 2, dtype: object
# 0    10771/16000
# Name: 2, dtype: object
# 0    810/50000
# Name: 2, dtype: object
# 0    14024/16000
# Name: 2, dtype: object
# 0    8721/16000
# Name: 2, dtype: object
# 0    15183/16000
# Name: 2, dtype: object
# 0    4062/16000
# Name: 2, dtype: object
# 0    1155/16000
# Name: 2, dtype: object
# 0    1402/16000
# Name: 2, dtype: object
# 0    14098/16000
# Name: 2, dtype: object
# 0    1947/16000
# Name: 2, dtype: object
# 0    2110/16000
# Name: 2, dtype: object
# 0    15112/16000
# Name: 2, dtype: object
# 0    13554/16000
# Name: 2, dtype: object
# 0    9815/16000
# Name: 2, dtype: object
# 0    8164/16000
# Name: 2, dtype: object
# 0    6307/16000
# Name: 2, dtype: object
# ...
