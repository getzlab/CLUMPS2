# %%
import pandas as pd
import numpy as np
import re

import glob
import os
#pdb structure list from Alphafold
afdir = '/home/adunford/afref/UP000005640_9606_HUMAN_v3/'
afpdblist = pd.Series([path.replace(afdir,'') for path in glob.glob('%s/*pdb.gz' % afdir)])


#prot2AF mapping - needed to loop over, scatter/gather all structures
#current version of clumps seems to depend on having the 4 character code in order to access pdb structures
#new version may have 1:1 uniprot:structure connection 
p2af = pd.DataFrame(columns=['u1', #uniprot id
                             'u2', #also uniprot iD (should be the same for AF, )
                             'struct', #name of structure/chain - 1 chain per peptide in AF?
                             'blat', #- not relevant for AF
                             'AA:AA list' #colon separated amino acid positions - should be 1:1, 2:2 etc. for AF? - revisit this
                            ])
p2af['u1'] = [x[1] for x in afpdblist.str.split('-')]
p2af['u2'] = p2af['u1']
p2af['blat'] = '-'
p2af

#p2af.index = p2af['u1']
p2af = p2af.sort_values('u1')


p2af.index = np.arange(0, len(p2af))
p2af

for i in np.arange(0,len(p2af.index)):
    afid = hex(int('1000',16)+i)[2:]
    g = p2af.index[i]
    p2af.iloc[i,2] = '%s-A' % afid

    

p2af
# Out:
#                u1          u2  struct blat AA:AA list
# 0      A0A024R1R8  A0A024R1R8  1000-A    -        NaN
# 1      A0A024RBG1  A0A024RBG1  1001-A    -        NaN
# 2      A0A024RCN7  A0A024RCN7  1002-A    -        NaN
# 3      A0A075B6H5  A0A075B6H5  1003-A    -        NaN
# 4      A0A075B6H7  A0A075B6H7  1004-A    -        NaN
# ...           ...         ...     ...  ...        ...
# 23386      U3KPV4      U3KPV4  6b5a-A    -        NaN
# 23387      V9GZ13      V9GZ13  6b5b-A    -        NaN
# 23388      W5XKT8      W5XKT8  6b5c-A    -        NaN
# 23389      W6CW81      W6CW81  6b5d-A    -        NaN
# 23390      X6R8D5      X6R8D5  6b5e-A    -        NaN
#
# [23391 rows x 5 columns]

# %%
import prody
from prody import parsePDBHeader
out_dir = 'af_dir'
if not os.path.exists(out_dir):
    os.mkdir(out_dir)
for uid in np.unique(p2af['u1']):
    nuid = sum(p2af['u1'] == uid)
    auid = len(afpdblist[afpdblist.str.contains(uid)])
    if nuid!=auid:
        msg = "%s entries of %s found in protein-af mapping, %s entries found in alphafold" % (nuid,uid,auid)
        print(msg)
    pstructs = p2af.loc[p2af['u1'] == uid,'struct'].values
    ix = p2af.loc[p2af['u1'] == uid].index
    for j in np.arange(0,nuid):
        afstruct = '%sAF-%s-F%s-model_v3.pdb.gz' % (afdir,uid,j+1)


        try:
            afheader = parsePDBHeader(afstruct)
        except:
            print('failed to load pdb struct for %s' %uid)
            continue

        afstart,_,gstart = afheader['A'].dbrefs[0].first
        afend,_,gend = afheader['A'].dbrefs[0].last
        aaaa = ''
        afaa = np.arange(afstart,afend)
        gaa = np.arange(gstart,gend)
        if len(gaa) != len(afaa):
            print('length mismatch for %s.  AF struct is length %s, while genomic length is %s' % (uid, len(afaa),len(gaa)))
            continue
        for i in     np.arange(0,len(afaa)):
            aai = '%s:%s ' %(gaa[i],afaa[i])
            aaaa = aaaa + (aai)
        #must remove trailing space or postprocessing will fail
        aaaa = aaaa.strip()
        p2af.loc[ix[j],'AA:AA list'] = aaaa


        if not os.path.exists(afstruct):
            print('file not found: %s' %afstruct)
            continue
        pstruct = pstructs[j]
        pstruct = str(pstruct[:-2])
        subdir=str(pstruct[1:3])
        cmd = 'cp %s %s/%s/pdb%s.ent.gz' %(afstruct,out_dir,subdir,pstruct)
        if not os.path.exists('%s/%s' %(out_dir,subdir)):
            os.mkdir('%s/%s' %(out_dir,subdir))
        os.system(cmd)
# Out:
# failed to load pdb struct for A0A024R1R8
# failed to load pdb struct for A0A024RBG1
# failed to load pdb struct for A0A024RCN7
# failed to load pdb struct for A0A075B6H5
# failed to load pdb struct for A0A075B6H7
# failed to load pdb struct for A0A075B6H8
# failed to load pdb struct for A0A075B6H9
# failed to load pdb struct for A0A075B6I0
# failed to load pdb struct for A0A075B6I1
# failed to load pdb struct for A0A075B6I3
# failed to load pdb struct for A0A075B6I4
# failed to load pdb struct for A0A075B6I6
# failed to load pdb struct for A0A075B6I7
# failed to load pdb struct for A0A075B6I9
# failed to load pdb struct for A0A075B6J1
# failed to load pdb struct for A0A075B6J2
# failed to load pdb struct for A0A075B6J6
# failed to load pdb struct for A0A075B6J9
# failed to load pdb struct for A0A075B6K0
# failed to load pdb struct for A0A075B6K2
# failed to load pdb struct for A0A075B6K4
# failed to load pdb struct for A0A075B6K5
# failed to load pdb struct for A0A075B6K6
# failed to load pdb struct for A0A075B6L2
# failed to load pdb struct for A0A075B6L6
# failed to load pdb struct for A0A075B6N1
# failed to load pdb struct for A0A075B6N2
# failed to load pdb struct for A0A075B6N3
# failed to load pdb struct for A0A075B6N4
# failed to load pdb struct for A0A075B6P5
# failed to load pdb struct for A0A075B6Q5
# failed to load pdb struct for A0A075B6R0
# failed to load pdb struct for A0A075B6R2
# failed to load pdb struct for A0A075B6R9
# failed to load pdb struct for A0A075B6S0
# failed to load pdb struct for A0A075B6S2
# failed to load pdb struct for A0A075B6S4
# failed to load pdb struct for A0A075B6S5
# failed to load pdb struct for A0A075B6S6
# failed to load pdb struct for A0A075B6S9
# failed to load pdb struct for A0A075B6T6
# failed to load pdb struct for A0A075B6T7
# failed to load pdb struct for A0A075B6T8
# failed to load pdb struct for A0A075B6U4
# failed to load pdb struct for A0A075B6U6
# failed to load pdb struct for A0A075B6V2
# failed to load pdb struct for A0A075B6V5
# failed to load pdb struct for A0A075B6W5
# failed to load pdb struct for A0A075B6X5
# failed to load pdb struct for A0A075B6Y3
# failed to load pdb struct for A0A075B6Y9
# failed to load pdb struct for A0A075B700
# failed to load pdb struct for A0A075B706
# failed to load pdb struct for A0A075B734
# failed to load pdb struct for A0A075B759
# failed to load pdb struct for A0A075B767
# failed to load pdb struct for A0A075B7B6
# failed to load pdb struct for A0A075B7B8
# failed to load pdb struct for A0A075B7D0
# failed to load pdb struct for A0A075B7D4
# failed to load pdb struct for A0A075B7D8
# failed to load pdb struct for A0A075B7E8
# failed to load pdb struct for A0A075B7F0
# failed to load pdb struct for A0A075B7F1
# failed to load pdb struct for A0A087WSX0
# failed to load pdb struct for A0A087WSY4
# failed to load pdb struct for A0A087WSY6
# failed to load pdb struct for A0A087WSZ0
# failed to load pdb struct for A0A087WSZ9
# failed to load pdb struct for A0A087WT01
# failed to load pdb struct for A0A087WT02
# failed to load pdb struct for A0A087WT03
# failed to load pdb struct for A0A087WTH1
# failed to load pdb struct for A0A087WTH5
# failed to load pdb struct for A0A087WUL8
# length mismatch for A0A087WUL8.  AF struct is length 1399, while genomic length is 14
# length mismatch for A0A087WUL8.  AF struct is length 1399, while genomic length is 14
# length mismatch for A0A087WUL8.  AF struct is length 1399, while genomic length is 14
# length mismatch for A0A087WUL8.  AF struct is length 1399, while genomic length is 14
# length mismatch for A0A087WUL8.  AF struct is length 1399, while genomic length is 14
# length mismatch for A0A087WUL8.  AF struct is length 1399, while genomic length is 14
# length mismatch for A0A087WUL8.  AF struct is length 1399, while genomic length is 14
# length mismatch for A0A087WUL8.  AF struct is length 1399, while genomic length is 14
# length mismatch for A0A087WUL8.  AF struct is length 1399, while genomic length is 14
# length mismatch for A0A087WUL8.  AF struct is length 1399, while genomic length is 14
# length mismatch for A0A087WUL8.  AF struct is length 1399, while genomic length is 14
# length mismatch for A0A087WUL8.  AF struct is length 1399, while genomic length is 14
# length mismatch for A0A087WUL8.  AF struct is length 1242, while genomic length is 12
# failed to load pdb struct for A0A087WUM9
# failed to load pdb struct for A0A087WUV0
# failed to load pdb struct for A0A087WV53
# failed to load pdb struct for A0A087WV62
# failed to load pdb struct for A0A087WVF3
# failed to load pdb struct for A0A087WW49
# failed to load pdb struct for A0A087WW87
# failed to load pdb struct for A0A087WWA1
# failed to load pdb struct for A0A087WX78
# failed to load pdb struct for A0A087WXM9
# failed to load pdb struct for A0A087WXS9
# failed to load pdb struct for A0A087WYE8
# failed to load pdb struct for A0A087WZ39
# failed to load pdb struct for A0A087X0K7
# failed to load pdb struct for A0A087X0M5
# failed to load pdb struct for A0A087X179
# failed to load pdb struct for A0A087X1C1
# failed to load pdb struct for A0A087X1C5
# failed to load pdb struct for A0A087X1G2
# failed to load pdb struct for A0A087X1L8
# failed to load pdb struct for A0A096LNP1
# failed to load pdb struct for A0A096LNT9
# failed to load pdb struct for A0A096LNW5
# failed to load pdb struct for A0A096LP01
# failed to load pdb struct for A0A096LP49
# failed to load pdb struct for A0A096LP55
# failed to load pdb struct for A0A096LPG2
# failed to load pdb struct for A0A096LPH7
# failed to load pdb struct for A0A096LPI5
# failed to load pdb struct for A0A096LPK6
# failed to load pdb struct for A0A096LPK9
# failed to load pdb struct for A0A0A0MRZ7
# failed to load pdb struct for A0A0A0MRZ8
# failed to load pdb struct for A0A0A0MRZ9
# failed to load pdb struct for A0A0A0MS00
# failed to load pdb struct for A0A0A0MS01
# failed to load pdb struct for A0A0A0MS02
# failed to load pdb struct for A0A0A0MS03
# failed to load pdb struct for A0A0A0MS04
# failed to load pdb struct for A0A0A0MS05
# failed to load pdb struct for A0A0A0MS06
# failed to load pdb struct for A0A0A0MS14
# failed to load pdb struct for A0A0A0MS15
# failed to load pdb struct for A0A0A0MT36
# failed to load pdb struct for A0A0A0MT70
# failed to load pdb struct for A0A0A0MT76
# failed to load pdb struct for A0A0A0MT82
# failed to load pdb struct for A0A0A0MT86
# failed to load pdb struct for A0A0A0MT87
# failed to load pdb struct for A0A0A0MT93
# failed to load pdb struct for A0A0A0MT94
# failed to load pdb struct for A0A0A0MT99
# failed to load pdb struct for A0A0A0MTA7
# failed to load pdb struct for A0A0A6YYC5
# failed to load pdb struct for A0A0A6YYD4
# failed to load pdb struct for A0A0A6YYG2
# failed to load pdb struct for A0A0A6YYG3
# failed to load pdb struct for A0A0A6YYJ7
# failed to load pdb struct for A0A0A6YYK1
# failed to load pdb struct for A0A0A6YYK4
# failed to load pdb struct for A0A0A6YYK6
# failed to load pdb struct for A0A0A6YYK7
# failed to load pdb struct for A0A0A6YYL3
# failed to load pdb struct for A0A0B4J1T7
# failed to load pdb struct for A0A0B4J1U3
# failed to load pdb struct for A0A0B4J1U4
# failed to load pdb struct for A0A0B4J1U6
# failed to load pdb struct for A0A0B4J1U7
# failed to load pdb struct for A0A0B4J1V0
# failed to load pdb struct for A0A0B4J1V1
# failed to load pdb struct for A0A0B4J1V2
# failed to load pdb struct for A0A0B4J1V6
# failed to load pdb struct for A0A0B4J1V7
# failed to load pdb struct for A0A0B4J1W7
# failed to load pdb struct for A0A0B4J1X5
# failed to load pdb struct for A0A0B4J1X8
# failed to load pdb struct for A0A0B4J1Y8
# failed to load pdb struct for A0A0B4J1Y9
# failed to load pdb struct for A0A0B4J1Z2
# failed to load pdb struct for A0A0B4J200
# failed to load pdb struct for A0A0B4J234
# failed to load pdb struct for A0A0B4J235
# failed to load pdb struct for A0A0B4J237
# failed to load pdb struct for A0A0B4J238
# failed to load pdb struct for A0A0B4J240
# failed to load pdb struct for A0A0B4J241
# failed to load pdb struct for A0A0B4J244
# failed to load pdb struct for A0A0B4J245
# failed to load pdb struct for A0A0B4J248
# failed to load pdb struct for A0A0B4J249
# failed to load pdb struct for A0A0B4J262
# failed to load pdb struct for A0A0B4J263
# failed to load pdb struct for A0A0B4J264
# failed to load pdb struct for A0A0B4J265
# failed to load pdb struct for A0A0B4J266
# failed to load pdb struct for A0A0B4J268
# failed to load pdb struct for A0A0B4J271
# failed to load pdb struct for A0A0B4J272
# failed to load pdb struct for A0A0B4J273
# failed to load pdb struct for A0A0B4J274
# failed to load pdb struct for A0A0B4J275
# failed to load pdb struct for A0A0B4J276
# failed to load pdb struct for A0A0B4J277
# failed to load pdb struct for A0A0B4J279
# failed to load pdb struct for A0A0B4J280
# failed to load pdb struct for A0A0B4J2A2
# failed to load pdb struct for A0A0B4J2B6
# failed to load pdb struct for A0A0B4J2B8
# failed to load pdb struct for A0A0B4J2D5
# failed to load pdb struct for A0A0B4J2D9
# failed to load pdb struct for A0A0B4J2E0
# failed to load pdb struct for A0A0B4J2E5
# failed to load pdb struct for A0A0B4J2F0
# failed to load pdb struct for A0A0B4J2F2
# failed to load pdb struct for A0A0B4J2H0
# failed to load pdb struct for A0A0C4DGP1
# failed to load pdb struct for A0A0C4DH24
# failed to load pdb struct for A0A0C4DH25
# failed to load pdb struct for A0A0C4DH26
# failed to load pdb struct for A0A0C4DH27
# failed to load pdb struct for A0A0C4DH28
# failed to load pdb struct for A0A0C4DH29
# failed to load pdb struct for A0A0C4DH30
# failed to load pdb struct for A0A0C4DH31
# failed to load pdb struct for A0A0C4DH32
# failed to load pdb struct for A0A0C4DH33
# failed to load pdb struct for A0A0C4DH34
# failed to load pdb struct for A0A0C4DH35
# failed to load pdb struct for A0A0C4DH36
# failed to load pdb struct for A0A0C4DH38
# failed to load pdb struct for A0A0C4DH39
# failed to load pdb struct for A0A0C4DH41
# failed to load pdb struct for A0A0C4DH42
# failed to load pdb struct for A0A0C4DH43
# failed to load pdb struct for A0A0C4DH55
# failed to load pdb struct for A0A0C4DH59
# failed to load pdb struct for A0A0C4DH62
# failed to load pdb struct for A0A0C4DH63
# failed to load pdb struct for A0A0C4DH67
# failed to load pdb struct for A0A0C4DH68
# failed to load pdb struct for A0A0C4DH69
# failed to load pdb struct for A0A0C4DH72
# failed to load pdb struct for A0A0C4DH73
# failed to load pdb struct for A0A0C4DH90
# failed to load pdb struct for A0A0C5B5G6
# failed to load pdb struct for A0A0D9SF12
# failed to load pdb struct for A0A0G2JKD1
# failed to load pdb struct for A0A0G2JKW9
# failed to load pdb struct for A0A0G2JLE6
# failed to load pdb struct for A0A0G2JLG4
# failed to load pdb struct for A0A0G2JLM5
# failed to load pdb struct for A0A0G2JLQ3
# failed to load pdb struct for A0A0G2JLW4
# failed to load pdb struct for A0A0G2JMD5
# failed to load pdb struct for A0A0G2JMH3
# failed to load pdb struct for A0A0G2JMH6
# failed to load pdb struct for A0A0G2JMI3
# failed to load pdb struct for A0A0G2JMM0
# failed to load pdb struct for A0A0G2JMP0
# failed to load pdb struct for A0A0G2JMS6
# failed to load pdb struct for A0A0G2JN01
# failed to load pdb struct for A0A0G2JN53
# failed to load pdb struct for A0A0G2JN68
# failed to load pdb struct for A0A0G2JND7
# failed to load pdb struct for A0A0G2JNF4
# failed to load pdb struct for A0A0G2JNG1
# failed to load pdb struct for A0A0G2JNH3
# failed to load pdb struct for A0A0G2JNJ9
# failed to load pdb struct for A0A0G2JNQ3
# failed to load pdb struct for A0A0G2JP20
# failed to load pdb struct for A0A0G2JPB7
# failed to load pdb struct for A0A0G2JPC4
# failed to load pdb struct for A0A0G2JPF8
# failed to load pdb struct for A0A0G2JPN4
# failed to load pdb struct for A0A0G2JQ47
# failed to load pdb struct for A0A0G2JQF1
# failed to load pdb struct for A0A0G2JQZ4
# failed to load pdb struct for A0A0G2JRQ6
# failed to load pdb struct for A0A0G2JS06
# failed to load pdb struct for A0A0J9YVY3
# failed to load pdb struct for A0A0J9YW62
# failed to load pdb struct for A0A0J9YWL9
# failed to load pdb struct for A0A0J9YWP8
# failed to load pdb struct for A0A0J9YWU9
# failed to load pdb struct for A0A0J9YWX3
# failed to load pdb struct for A0A0J9YX35
# failed to load pdb struct for A0A0J9YX57
# failed to load pdb struct for A0A0J9YX75
# failed to load pdb struct for A0A0J9YX94
# failed to load pdb struct for A0A0J9YXG5
# failed to load pdb struct for A0A0J9YXM7
# failed to load pdb struct for A0A0J9YXQ4
# failed to load pdb struct for A0A0J9YXV3
# failed to load pdb struct for A0A0J9YXX1
# failed to load pdb struct for A0A0J9YXY3
# failed to load pdb struct for A0A0J9YY54
# failed to load pdb struct for A0A0J9YY99
# failed to load pdb struct for A0A0K0K1A3
# failed to load pdb struct for A0A0K0K1A5
# failed to load pdb struct for A0A0K0K1B3
# failed to load pdb struct for A0A0K0K1C0
# failed to load pdb struct for A0A0K0K1C4
# failed to load pdb struct for A0A0K0K1D8
# failed to load pdb struct for A0A0K0K1E9
# failed to load pdb struct for A0A0K0K1G6
# failed to load pdb struct for A0A0K0K1G8
# failed to load pdb struct for A0A0K2S4Q6
# failed to load pdb struct for A0A0M3HER8
# failed to load pdb struct for A0A0U1RQE8
# failed to load pdb struct for A0A0U1RQF7
# failed to load pdb struct for A0A0U1RQG5
# failed to load pdb struct for A0A0U1RQI7
# failed to load pdb struct for A0A0U1RQS6
# failed to load pdb struct for A0A0U1RR11
# failed to load pdb struct for A0A0U1RR37
# failed to load pdb struct for A0A0U1RRA0
# failed to load pdb struct for A0A0U1RRE5
# failed to load pdb struct for A0A0U1RRI6
# failed to load pdb struct for A0A0U1RRK4
# failed to load pdb struct for A0A0U1RRL7
# failed to load pdb struct for A0A0U1RRN3
# failed to load pdb struct for A0A0X1KG70
# failed to load pdb struct for A0A126GWB0
# failed to load pdb struct for A0A126GWI2
# failed to load pdb struct for A0A140G945
# failed to load pdb struct for A0A140T8X8
# failed to load pdb struct for A0A140TA62
# failed to load pdb struct for A0A140TA64
# failed to load pdb struct for A0A140TA67
# failed to load pdb struct for A0A191URJ7
# failed to load pdb struct for A0A1B0GTC6
# failed to load pdb struct for A0A1B0GTD5
# failed to load pdb struct for A0A1B0GTE1
# failed to load pdb struct for A0A1B0GTG8
# failed to load pdb struct for A0A1B0GTH6
# failed to load pdb struct for A0A1B0GTH9
# failed to load pdb struct for A0A1B0GTI1
# failed to load pdb struct for A0A1B0GTI8
# failed to load pdb struct for A0A1B0GTJ6
# failed to load pdb struct for A0A1B0GTK4
# failed to load pdb struct for A0A1B0GTK5
# failed to load pdb struct for A0A1B0GTL2
# failed to load pdb struct for A0A1B0GTQ1
# failed to load pdb struct for A0A1B0GTQ4
# failed to load pdb struct for A0A1B0GTR0
# failed to load pdb struct for A0A1B0GTR3
# failed to load pdb struct for A0A1B0GTR4
# failed to load pdb struct for A0A1B0GTS1
# failed to load pdb struct for A0A1B0GTU1
# failed to load pdb struct for A0A1B0GTU2
# failed to load pdb struct for A0A1B0GTW7
# failed to load pdb struct for A0A1B0GTY4
# failed to load pdb struct for A0A1B0GTZ2
# failed to load pdb struct for A0A1B0GU29
# failed to load pdb struct for A0A1B0GU33
# failed to load pdb struct for A0A1B0GU71
# failed to load pdb struct for A0A1B0GUA5
# failed to load pdb struct for A0A1B0GUA6
# failed to load pdb struct for A0A1B0GUA7
# failed to load pdb struct for A0A1B0GUA9
# failed to load pdb struct for A0A1B0GUC4
# failed to load pdb struct for A0A1B0GUI7
# failed to load pdb struct for A0A1B0GUJ8
# failed to load pdb struct for A0A1B0GUL7
# failed to load pdb struct for A0A1B0GUQ0
# failed to load pdb struct for A0A1B0GUS0
# failed to load pdb struct for A0A1B0GUS4
# failed to load pdb struct for A0A1B0GUT2
# failed to load pdb struct for A0A1B0GUU1
# failed to load pdb struct for A0A1B0GUV1
# failed to load pdb struct for A0A1B0GUV7
# failed to load pdb struct for A0A1B0GUV8
# failed to load pdb struct for A0A1B0GUW6
# failed to load pdb struct for A0A1B0GUW7
# failed to load pdb struct for A0A1B0GUX0
# failed to load pdb struct for A0A1B0GUY1
# failed to load pdb struct for A0A1B0GUZ9
# failed to load pdb struct for A0A1B0GV03
# failed to load pdb struct for A0A1B0GV22
# failed to load pdb struct for A0A1B0GV85
# failed to load pdb struct for A0A1B0GV90
# failed to load pdb struct for A0A1B0GV96
# failed to load pdb struct for A0A1B0GVB3
# failed to load pdb struct for A0A1B0GVD1
# failed to load pdb struct for A0A1B0GVG4
# failed to load pdb struct for A0A1B0GVG6
# failed to load pdb struct for A0A1B0GVH4
# failed to load pdb struct for A0A1B0GVH6
# failed to load pdb struct for A0A1B0GVH7
# failed to load pdb struct for A0A1B0GVK7
# failed to load pdb struct for A0A1B0GVM5
# failed to load pdb struct for A0A1B0GVM6
# failed to load pdb struct for A0A1B0GVN3
# failed to load pdb struct for A0A1B0GVQ0
# failed to load pdb struct for A0A1B0GVQ3
# failed to load pdb struct for A0A1B0GVR7
# failed to load pdb struct for A0A1B0GVS7
# failed to load pdb struct for A0A1B0GVT2
# failed to load pdb struct for A0A1B0GVV1
# failed to load pdb struct for A0A1B0GVX0
# failed to load pdb struct for A0A1B0GVY2
# failed to load pdb struct for A0A1B0GVY4
# failed to load pdb struct for A0A1B0GVZ2
# failed to load pdb struct for A0A1B0GVZ6
# failed to load pdb struct for A0A1B0GVZ9
# failed to load pdb struct for A0A1B0GW15
# failed to load pdb struct for A0A1B0GW35
# failed to load pdb struct for A0A1B0GW54
# failed to load pdb struct for A0A1B0GW64
# failed to load pdb struct for A0A1B0GWB2
# failed to load pdb struct for A0A1B0GWG4
# failed to load pdb struct for A0A1B0GWH4
# failed to load pdb struct for A0A1B0GWH6
# failed to load pdb struct for A0A1B0GWI6
# failed to load pdb struct for A0A1B0GWK0
# failed to load pdb struct for A0A1B0GX31
# failed to load pdb struct for A0A1B0GX49
# failed to load pdb struct for A0A1B0GX51
# failed to load pdb struct for A0A1B0GX56
# failed to load pdb struct for A0A1B0GX68
# failed to load pdb struct for A0A1B0GX78
# failed to load pdb struct for A0A1B0GX95
# failed to load pdb struct for A0A1B0GXF2
# failed to load pdb struct for A0A1W2PN81
# failed to load pdb struct for A0A1W2PNU3
# failed to load pdb struct for A0A1W2PP81
# failed to load pdb struct for A0A1W2PP97
# failed to load pdb struct for A0A1W2PPD8
# failed to load pdb struct for A0A1W2PPE2
# failed to load pdb struct for A0A1W2PPE3
# failed to load pdb struct for A0A1W2PPF3
# failed to load pdb struct for A0A1W2PPG7
# failed to load pdb struct for A0A1W2PPH5
# failed to load pdb struct for A0A1W2PPK0
# failed to load pdb struct for A0A1W2PPL8
# failed to load pdb struct for A0A1W2PPM0
# failed to load pdb struct for A0A1W2PPM1
# failed to load pdb struct for A0A1W2PPW3
# failed to load pdb struct for A0A1W2PQ09
# failed to load pdb struct for A0A1W2PQ27
# failed to load pdb struct for A0A1W2PQ64
# failed to load pdb struct for A0A1W2PQ72
# failed to load pdb struct for A0A1W2PQ73
# failed to load pdb struct for A0A1W2PQC6
# failed to load pdb struct for A0A1W2PQD8
# failed to load pdb struct for A0A1W2PQF6
# failed to load pdb struct for A0A1W2PQJ5
# failed to load pdb struct for A0A1W2PQL4
# failed to load pdb struct for A0A1W2PQM1
# failed to load pdb struct for A0A1W2PQU2
# failed to load pdb struct for A0A1W2PR19
# failed to load pdb struct for A0A1W2PR48
# failed to load pdb struct for A0A1W2PR64
# failed to load pdb struct for A0A1W2PR75
# failed to load pdb struct for A0A1W2PR80
# failed to load pdb struct for A0A1W2PR82
# failed to load pdb struct for A0A1W2PR95
# failed to load pdb struct for A0A1W2PRE2
# failed to load pdb struct for A0A1W2PRG0
# failed to load pdb struct for A0A1W2PRN1
# failed to load pdb struct for A0A1W2PRN6
# failed to load pdb struct for A0A1W2PRP0
# failed to load pdb struct for A0A1W2PRS3
# failed to load pdb struct for A0A1W2PRV1
# failed to load pdb struct for A0A1W2PS18
# failed to load pdb struct for A0A286YEU6
# failed to load pdb struct for A0A286YEV6
# failed to load pdb struct for A0A286YEX9
# failed to load pdb struct for A0A286YEY9
# failed to load pdb struct for A0A286YF01
# failed to load pdb struct for A0A286YF18
# failed to load pdb struct for A0A286YF46
# failed to load pdb struct for A0A286YF58
# failed to load pdb struct for A0A286YF60
# failed to load pdb struct for A0A286YF77
# failed to load pdb struct for A0A286YFB4
# failed to load pdb struct for A0A286YFG1
# failed to load pdb struct for A0A286YFK9
# failed to load pdb struct for A0A2R8Y2Y2
# failed to load pdb struct for A0A2R8Y422
# failed to load pdb struct for A0A2R8Y4L2
# failed to load pdb struct for A0A2R8Y4L6
# failed to load pdb struct for A0A2R8Y4M2
# failed to load pdb struct for A0A2R8Y4M4
# failed to load pdb struct for A0A2R8Y4Y8
# failed to load pdb struct for A0A2R8Y556
# failed to load pdb struct for A0A2R8Y5M8
# failed to load pdb struct for A0A2R8Y619
# failed to load pdb struct for A0A2R8Y747
# failed to load pdb struct for A0A2R8Y7D0
# failed to load pdb struct for A0A2R8Y7Y5
# failed to load pdb struct for A0A2R8YCJ5
# failed to load pdb struct for A0A2R8YCY7
# failed to load pdb struct for A0A2R8YD15
# failed to load pdb struct for A0A2R8YE69
# failed to load pdb struct for A0A2R8YED5
# failed to load pdb struct for A0A2R8YEG4
# failed to load pdb struct for A0A2R8YEH3
# failed to load pdb struct for A0A2R8YEV3
# failed to load pdb struct for A0A2R8YFL7
# failed to load pdb struct for A0A2R8YFM6
# failed to load pdb struct for A0A2R8YFR7
# failed to load pdb struct for A0A2U3TZM8
# failed to load pdb struct for A0A2Z4LIS9
# failed to load pdb struct for A0A376A8Z9
# failed to load pdb struct for A0A3B3IRQ3
# failed to load pdb struct for A0A3B3IRS2
# failed to load pdb struct for A0A3B3IRV3
# failed to load pdb struct for A0A3B3IT33
# failed to load pdb struct for A0A3B3IT34
# failed to load pdb struct for A0A3B3IT45
# failed to load pdb struct for A0A3B3IT52
# failed to load pdb struct for A0A3B3IU46
# failed to load pdb struct for A0A3B3IU63
# failed to load pdb struct for A0A494BZU2
# failed to load pdb struct for A0A494BZU4
# failed to load pdb struct for A0A494BZZ5
# failed to load pdb struct for A0A494C030
# failed to load pdb struct for A0A494C071
# failed to load pdb struct for A0A494C086
# failed to load pdb struct for A0A494C0B9
# failed to load pdb struct for A0A494C0I6
# failed to load pdb struct for A0A494C0N9
# failed to load pdb struct for A0A494C0Y3
# failed to load pdb struct for A0A494C0Z2
# failed to load pdb struct for A0A494C103
# failed to load pdb struct for A0A494C162
# failed to load pdb struct for A0A494C176
# failed to load pdb struct for A0A494C191
# failed to load pdb struct for A0A494C193
# failed to load pdb struct for A0A494C1I1
# failed to load pdb struct for A0A494C1R9
# failed to load pdb struct for A0A499FJF3
# failed to load pdb struct for A0A4W9AIG4
# failed to load pdb struct for A0A590UJ96
# failed to load pdb struct for A0A590UK24
# failed to load pdb struct for A0A590UK83
# failed to load pdb struct for A0A5F9Z9Y6
# failed to load pdb struct for A0A5F9ZGZ6
# failed to load pdb struct for A0A5F9ZH02
# failed to load pdb struct for A0A5F9ZH88
# failed to load pdb struct for A0A5F9ZHI8
# failed to load pdb struct for A0A5F9ZHS0
# failed to load pdb struct for A0A5F9ZHS7
# failed to load pdb struct for A0A5F9ZHU2
# failed to load pdb struct for A0A5K1VDZ0
# failed to load pdb struct for A0A5S8K742
# failed to load pdb struct for A0A669KAW2
# failed to load pdb struct for A0A669KB60
# failed to load pdb struct for A0A6I8PS25
# failed to load pdb struct for A0A6I8PU40
# failed to load pdb struct for A0A6Q8PFC9
# failed to load pdb struct for A0A6Q8PFD8
# failed to load pdb struct for A0A6Q8PFQ6
# failed to load pdb struct for A0A6Q8PGL7
# failed to load pdb struct for A0A6Q8PGS0
# failed to load pdb struct for A0A6Q8PGZ6
# failed to load pdb struct for A0A6Q8PGZ7
# failed to load pdb struct for A0A6Q8PHA8
# failed to load pdb struct for A0A6Q8PHR7
# failed to load pdb struct for A0A6Q8PHS2
# failed to load pdb struct for A0A7E1QX52
# failed to load pdb struct for A0A7I2V2S6
# failed to load pdb struct for A0A7I2V3D3
# failed to load pdb struct for A0A7I2V3R4
# failed to load pdb struct for A0A7I2V4K3
# failed to load pdb struct for A0A7I2V4U8
# failed to load pdb struct for A0A7I2V5U8
# failed to load pdb struct for A0A7I2V6D3
# length mismatch for Q8WXI7.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WXI7.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WXI7.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WXI7.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WXI7.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WXI7.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WXI7.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WXI7.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WXI7.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WXI7.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WXI7.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WXI7.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WXI7.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WXI7.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WXI7.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WXI7.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WXI7.  AF struct is length 1306, while genomic length is 11306
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 11399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 21399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 31399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 31399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 31399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 31399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 31399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 31399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 31399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 31399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 31399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 31399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 31399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 31399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 31399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 31399
# length mismatch for Q8WZ42.  AF struct is length 1399, while genomic length is 31399
# length mismatch for Q8WZ42.  AF struct is length 1349, while genomic length is 31349

# %%
p2af = p2af.loc[~p2af['AA:AA list'].isna()]

# %%
#print out list of prot2AF mapping
p2af.to_csv('uniprot2af_map.txt',
            sep='\t',
            header=False,
            index=False)

# %%
out_dir = 'prot2AF_chunks'
chunk_length= 75
if not os.path.exists(out_dir):
    os.mkdir(out_dir)
gl = len(p2af.index)
start = 0
end = chunk_length
i = 0
while end < gl:
    if i < 10:
        num = '0000%s' %i
    elif i < 100:
        num = '000%s' %i
    elif i < 1000:
        num = '00%s' %i
    fn = 'prot2AF_chunks/prot2af_%s.gz' %num
    p2af.iloc[start:end].to_csv(fn,
            sep='\t',
            header=False,
            index=False)
    i = i + 1
    start = end
    end = end+chunk_length
end = gl


if i < 10:
    num = '0000%s' %i
elif i < 100:
    num = '000%s' %i
elif i < 1000:
    num = '00%s' %i
fn = 'prot2AF_chunks/prot2af_%s.gz' %num

p2af.iloc[start:end].to_csv(fn,
        sep='\t',
        header=False,
        index=False)

# %%
#may not need gpmap in this script; moving to the end
#Do consider what work needs to be done to generate new gpmap; may have slightly different mapping for
#genome proteome AA positions
gpmapheader =[
    'chr',
    'gp1',
    'gp2',
    'exons',
    'strand',
    'uniprotid',
    'AA_list',
    'unknown']

gpmap = pd.read_csv('/mnt/nfs/ro_disks/canine-b7f9872002626d1a514fcdf5e295a8bd/gpmaps/genomeProteomeMaps.txt',
                   header =None,
                   sep = '\t')
gpmap

gpmap.columns = gpmapheader
gpmap.index = gpmap['uniprotid']
gpmap
# Out:
#            0          1          2  \
# 0       chr3  196439406  196460770
# 1      chr12   42706871   42717904
# 2       chr2   55777049   55844421
# 3      chr11   47640387   47664017
# 4      chr11   93212178   93212355
# ...      ...        ...        ...
# 20186  chr10   70105527   70166813
# 20187  chr11  125616199  125618625
# 20188   chr8   64081436   64122261
# 20189   chr8   12580607   12612929
# 20190   chr1  193091330  193219839
#
#                                                        3  4       5  \
# 0      196439406-196439515,196443728-196443792,196449...  +  Q8TBF5
# 1      42706871-42707000,42707491-42707567,42707675-4...  -  Q8TBF4
# 2      55777049-55777142,55785910-55786104,55791448-5...  -  Q5MIZ7
# 3      47640387-47640471,47644252-47644328,47647225-4...  -  Q9Y6C9
# 4                                      93212178-93212355  -  Q9NRQ5
# ...                                                  ... ..     ...
# 20186  70105527-70105668,70105763-70105841,70115109-7...  -  Q8WXA3
# 20187  125616199-125616251,125616555-125616591,125617...  +  Q8WXA2
# 20188  64081436-64081460,64081945-64081970,64087889-6...  +  Q7Z739
# 20189  12580607-12580763,12583235-12583388,12586409-1...  -  Q17RB8
# 20190  193091330-193091461,193094241-193094347,193099...  +  Q6P1J9
#
#                                                        6    7
# 0      1.0-37.1,37.1-58.2,58.2-106.0,106.0-177.1,177....  NaN
# 1      174.0-217.0,148.2-174.0,111.0-148.2,75.0-111.0...  NaN
# 2      818.0-849.0,753.1-818.0,691.2-753.1,645.0-691....  NaN
# 3      275.0-303.0,249.2-275.0,227.0-249.2,211.0-227....  NaN
# 4                                               0.0-59.0  NaN
# ...                                                  ...  ...
# 20186  608.0-655.0,582.0-608.0,565.2-582.0,534.0-565....  NaN
# 20187  0.0-17.1,17.1-29.1,29.1-41.1,41.1-82.1,82.1-126.0  NaN
# 20188  0.0-8.0,8.0-16.1,16.1-45.0,45.0-53.0,54.0-578....  NaN
# 20189  721.0-773.0,670.0-721.0,615.2-670.0,562.2-615....  NaN
# 20190  0.0-43.2,43.2-79.0,79.0-102.1,102.1-123.1,123....  NaN
#
# [20191 rows x 8 columns]

# %%
p2pdb = pd.read_csv('/mnt/nfs/ro_disks/canine-b7f9872002626d1a514fcdf5e295a8bd/prot2pdb_chunks/huniprot2pdb.run18_chunks/huniprot2pdb_chunk_00000.gz',
                    header =None,
                    sep='\t')

p2pdb

# %%
print(len(p2af.index))
p2af = p2af.loc[p2af['u1'].isin(gpmap['uniprotid'])]
print(len(p2af.index))
# Out:
# 23391
# 22627

# %%
    if(nuid ==1):
        afstruct = '%sAF-%s-F%s-model_v3.pdb.gz' % (afdir,uid,1)
        try:
            afheader = parsePDBHeader(afstruct)
        except:
            print('failed to load pdb struct for %s' %uid)
            continue
        afstart,_,gstart = afheader['A'].dbrefs[0].first
        afend,_,gend = afheader['A'].dbrefs[0].last
        aaaa = ''
        afaa = np.arange(afstart,afend)
        gaa = np.arange(gstart,gend)
        if len(gaa) != len(afaa):
            print('length mismatch for %s.  AF struct is length %s, while genomic length is %' % (uid, len(afaa),len(gaa)))
            continue
        for i in     np.arange(0,len(afaa)):
            aai = '%s:%s ' %(gaa[i],afaa[i])
            aaaa = aaaa + (aai)
        #must remove trailing space or postprocessing will fail
        aaaa = aaaa.strip()
        p2af.loc[p2af['u1'] == uid,'AA:AA list'] = aaaa
        pstruct = str(pstructs[:-2])
        subdir=str(pstruct[1:3])
        cmd = 'cp %s %s/%s/pdb%s.ent.gz' %(afstruct,out_dir,subdir,pstruct)
        #print(cmd)
        if not os.path.exists('%s/%s' %(out_dir,subdir)):
            os.mkdir('%s/%s' %(out_dir,subdir))
        os.system(cmd)
    else:
        ix = p2af.loc[p2af['u1'] == uid].index
        for j in np.arange(0,nuid):
            afstruct = '%sAF-%s-F%s-model_v3.pdb.gz' % (afdir,uid,j+1)
            
            
            try:
                afheader = parsePDBHeader(afstruct)
            except:
                print('failed to load pdb struct for %s' %uid)
                continue

            afstart,_,gstart = afheader['A'].dbrefs[0].first
            afend,_,gend = afheader['A'].dbrefs[0].last
            aaaa = ''
            afaa = np.arange(afstart,afend)
            gaa = np.arange(gstart,gend)
            if len(gaa) != len(afaa):
                print('length mismatch for %s.  AF struct is length %s, while genomic length is %s' % (uid, len(afaa),len(gaa)))
                continue
            for i in     np.arange(0,len(afaa)):
                aai = '%s:%s ' %(gaa[i],afaa[i])
                aaaa = aaaa + (aai)
            #must remove trailing space or postprocessing will fail
            aaaa = aaaa.strip()
            p2af.loc[ix[j],'AA:AA list'] = aaaa

            
            if not os.path.exists(afstruct):
                print('file not found: %s' %afstruct)
                continue
            pstruct = pstructs[j]
            pstruct = str(pstruct[:-2])
            subdir=str(pstruct[1:3])
            cmd = 'cp %s %s/%s/pdb%s.ent.gz' %(afstruct,out_dir,subdir,pstruct)
            if not os.path.exists('%s/%s' %(out_dir,subdir)):
                os.mkdir('%s/%s' %(out_dir,subdir))
            os.system(cmd)
